# %% [markdown]
# # Средњошколци у Републици Србији

# %% [markdown]
# # Група 2

# %% [markdown]
# Нацртати график просечан број ученика по одељењу.

# %% [markdown]
# x оса: Просечан број ученика по одељењу

# %% [markdown]
# y оса: Број одељења са одговарајућим бројем ученика

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Податке учитати из датотеке 'podaci/MPNTRopendata_sskole_pripremljeni.csv'
