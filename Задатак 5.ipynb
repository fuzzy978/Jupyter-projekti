# %% [markdown]
# # Средњошколци у Републици Србији

# %% [markdown]
# # Група 5

# %% [markdown]
# Нацртати график проценат ученика (дечака-девојчица) према подручју рада.

# %% [markdown]
# x оса: Проценат ученика

# %% [markdown]
# y оса: Подручје рада

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Податке учитати из датотеке 'podaci/MPNTRopendata_ss_pripremljeni.csv'
