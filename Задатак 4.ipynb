# %% [markdown]
# # Средњошколци у Републици Србији

# %% [markdown]
# # Група 4

# %% [markdown]
# Нацртати график број ученика по образовном профилу за подручје рада: 'Ekonomija, pravo i administracija'.

# %% [markdown]
# x оса: Број средњошколаца

# %% [markdown]
# y оса: Образовни профил

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Податке учитати из датотеке 'podaci/MPNTRopendata_ss_pripremljeni.csv'
