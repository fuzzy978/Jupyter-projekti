# %% [markdown]
# # Средњошколци у Републици Србији

# %% [markdown]
# # Група 1

# %% [markdown]
# Нацртати график где су школе поређане по величини (број ученика у растућем редоследу).

# %% [markdown]
# x оса: Школе поређане од најмање до највеће по броју ученика

# %% [markdown]
# y оса: Број ученика у средњој школи

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Податке учитати из датотеке 'podaci/MPNTRopendata_sskole_pripremljeni.csv'
