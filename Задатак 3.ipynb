# %% [markdown]
# # Средњошколци у Републици Србији

# %% [markdown]
# # Група 3

# %% [markdown]
# Нацртати график број ученика по подручју рада.

# %% [markdown]
# x оса: Број средњошколаца

# %% [markdown]
# y оса: Подручје рада

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Податке учитати из датотеке 'podaci/MPNTRopendata_ss_pripremljeni.csv'
